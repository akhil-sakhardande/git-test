# %% [markdown]
# # Tips: Quick Data Analysis

# %%
! pip freeze | grep pandas
# Out:
# pandas==0.25.1
# pandas-datareader==0.7.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(72)

# %%
np.random.randn(10,2)
# Out:
# array([[ 0.40442541, -0.18562755],
#        [ 0.01822964, -1.32254118],
#        [ 0.14084131, -0.14050175],
#        [-1.44731169,  0.21052757],
#        [ 2.08123001,  0.36584788],
#        [-0.06191737, -1.08868068],
#        [-0.15916716, -1.33487894],
#        [ 2.59982779,  0.94917439],
#        [-0.67511415,  0.63294372],
#        [-0.13031526,  0.15188933]])

# %%
np.random.seed(72)
line = pd.DataFrame(np.random.randn(1000,2),columns=["line1","line2"]).cumsum()
line.plot()

# %% [markdown]
# using a new library <b>cufflinks</b> for interactive plots <BR>! pip install cufflinks --upgrade

# %% [markdown]
# When installed cufflinks, you can create some very interesting interactive plots.
# <br> import cufflinks as cf
# <br> cf.go_offline()
# <br> df.iplot()

# %% [markdown]
# ## Magic commands in IPython

# %% [markdown]
# %lsmagic: Find all magic commandas available.
# <br> %debug: Interactive debugging
# <br> %store: Pass variables between notebooks. Code examples.
# <br> %who: List all variables of global scope.
# <br> %%time: Timing with magic.
# <br> %%writefile: Write the cell-content to a file.
